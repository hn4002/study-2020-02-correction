# %%
import pandas
import matplotlib.pyplot

# %%
er_stats_all = pandas.read_csv("ER_stats.csv")
er_stats_all.head()
# Out:
#    Unnamed: 0   ER  Avg.Correction  Max.Correction  Min.Correction  \
# 0           0  1.0      -39.598457       11.009174      -79.200432
# 1           1  2.0      -42.896502       38.773975      -85.421995
# 2           2  3.0      -37.637709       63.064659      -86.084142
# 3           3  4.0      -43.204065        7.807933      -81.393939
# 4           4  5.0      -37.847018       63.054187      -84.289655
#
#    Avg.Advance  Max.Advance  Min.Advance  Avg.Recovery  Max.Recovery  \
# 0    54.656113   241.034483   -77.214286     -9.036608    128.853383
# 1    51.066235   301.242236   -50.650000    -17.740945    130.714286
# 2    49.300610   199.465241   -25.433526    -16.773921     52.435784
# 3    60.334462   252.352807   -19.512195    -10.494539     87.528345
# 4    46.444095   433.180026   -37.737378    -15.258939    148.559671
#
#    Min.Recovery
# 0    -84.765998
# 1    -82.227621
# 2    -67.713043
# 3    -80.239604
# 4    -84.501754

# %%
er_stats = er_stats_all[['ER', 'Avg.Correction', 'Avg.Advance', 'Avg.Recovery']]
er_stats.head()
# Out:
#     ER  Avg.Correction  Avg.Advance  Avg.Recovery
# 0  1.0      -39.598457    54.656113     -9.036608
# 1  2.0      -42.896502    51.066235    -17.740945
# 2  3.0      -37.637709    49.300610    -16.773921
# 3  4.0      -43.204065    60.334462    -10.494539
# 4  5.0      -37.847018    46.444095    -15.258939

# %%
ax = er_stats.plot(title="EPS Rating Study", x="ER", figsize=(15, 9), grid=True, legend=True)
ax.set_ylabel("% Change")
ax.set_xlabel("EPS Rating")
# Out:
# Text(0.5, 0, 'EPS Rating')
