# %%
import pandas
import matplotlib.pyplot as plt

# %%
rating='EPS Rating'
ratingS='EPSRating'
df1 = pandas.read_csv("results/stats-H1-2019-{}.csv".format(ratingS), names=['X', rating, 'H1-2009'], skiprows=[0])
df1.head()
# Out:
#    X  EPS Rating    H1-2009
# 0  0         1.0        NaN
# 1  1         2.0  12.890240
# 2  2         3.0  -2.194997
# 3  3         4.0  -0.179725
# 4  4         5.0   7.289306

# %%
df2 = pandas.read_csv("results/stats-H2-2019-{}.csv".format(ratingS), names=['X', rating, 'H2-2009'], skiprows=[0])
df2.head()
# Out:
#    X  EPS Rating    H2-2009
# 0  0         1.0   2.508932
# 1  1         2.0 -17.007525
# 2  2         3.0  -3.794826
# 3  3         4.0 -13.939657
# 4  4         5.0   1.719647

# %%
df3 = pandas.read_csv("results/stats-Year-2019-{}.csv".format(ratingS), names=['X', rating, 'Year-2009'], skiprows=[0])
df3.head()
# Out:
#    X  EPS Rating  Year-2009
# 0  0         1.0        NaN
# 1  1         2.0  28.661764
# 2  2         3.0  -3.520597
# 3  3         4.0  34.662472
# 4  4         5.0  15.019385

# %%
ax = df1.plot(title="{} Study".format(rating), x=rating, y='H1-2009', figsize=(15, 9), grid=True, legend=True)
ax.set_ylabel("% Change")
ax.set_xlabel(rating)
df2.plot(ax=ax, x=rating, y='H2-2009', grid=True, legend=True)
df3.plot(ax=ax, x=rating, y='Year-2009', grid=True, legend=True)
plt.savefig("plot-{}.png".format(ratingS))
