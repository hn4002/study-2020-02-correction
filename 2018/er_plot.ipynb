# %%
import pandas
import matplotlib.pyplot

# %%
er_stats_all = pandas.read_csv("Year-2018-EPSRating-stats.csv")
er_stats_all.head()
# Out:
#    Unnamed: 0  EPS Rating  Avg. Advance
# 0           0         1.0           NaN
# 1           1         2.0     28.661764
# 2           2         3.0     -3.520597
# 3           3         4.0     34.662472
# 4           4         5.0     15.019385

# %%
ax = er_stats_all.plot(title="EPS Rating Study", x="EPS Rating", y="Avg. Advance", figsize=(15, 9), grid=True, legend=True)
ax.set_ylabel("% Change")
ax.set_xlabel("EPS Rating")
# Out:
# Text(0.5, 0, 'EPS Rating')
